# %% [markdown]
# # ¡Hola  !🙋🏻‍♂️
#
# Te escribe Lisandro Saez, soy revisor de código en Tripleten y tengo el agrado de revisar el proyecto que entregaste.
#
# Para simular la dinámica de un ambiente de trabajo, si veo algún error, en primer instancia solo los señalaré, dándote la oportunidad de encontrarlos y corregirlos por tu cuenta. En un trabajo real, el líder de tu equipo hará una dinámica similar. En caso de que no puedas resolver la tarea, te daré una información más precisa en la próxima revisión.
#
# Encontrarás mis comentarios más abajo - **por favor, no los muevas, no los modifiques ni los borres**.
#
# ¿Cómo lo voy a hacer? Voy a leer detenidamente cada una de las implementaciones que has llevado a cabo para cumplir con lo solicitado. Verás los comentarios de esta forma:
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si todo está perfecto.
# </div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si tu código está bien pero se puede mejorar o hay algún detalle que le hace falta. Se aceptan uno o dos comentarios de este tipo en el borrador, pero si hay más, deberías hacer las correcciones. Es como una tarea de prueba al solicitar un trabajo: muchos pequeños errores pueden hacer que un candidato sea rechazado.
# </div>
#
# <div class="alert alert-block alert-danger">
#
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Si de pronto hace falta algo o existe algún problema con tu código o conclusiones.
# </div>
#
# Puedes responderme de esta forma (no te preocupes, no es obligatorio):
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Hola, muchas gracias por tus comentarios y la revisión.
# </div>
#
# ¡Empecemos!

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan de solución para el Paso 1. Descripción de los datos.

# %%
import pandas as pd

# %%
# Cargar los archivos CSV con el separador ";"
orders_df = pd.read_csv('/datasets/instacart_orders.csv', sep=';')
products_df = pd.read_csv('/datasets/products.csv', sep=';')
order_products_df = pd.read_csv('/datasets/order_products.csv', sep=';')
aisles_df = pd.read_csv('/datasets/aisles.csv', sep=';')
departments_df = pd.read_csv('/datasets/departments.csv', sep=';')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Bien corregido! Se que puede ser un poco engorroso y hasta frustrante, pero son estas pequeñas cosas que le dan un toque extra de profesionalismo a tu trabajo que siempre se agradece!</div>

# %%
# Verificar la estructura de cada DataFrame

# Orders DataFrame
print("Orders DataFrame:")
print(orders_df.info())  # Información general sobre el DataFrame
print(orders_df.head())  # Muestra las primeras 5 filas
print("Valores nulos en orders_df:", orders_df.isnull().sum())  # Verificar valores nulos
print("Valores duplicados en orders_df:", orders_df.duplicated().sum())  # Verificar registros duplicados
print("\n")
# Out:
# Orders DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB
# None
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# ...

# %%
# Products DataFrame
print("Products DataFrame:")
print(products_df.info())  # Información general sobre el DataFrame
print(products_df.head())  # Muestra las primeras 5 filas
print("Valores nulos en products_df:", products_df.isnull().sum())  # Verificar valores nulos
print("Valores duplicados en products_df:", products_df.duplicated().sum())  # Verificar registros duplicados
print("\n")
# Out:
# Products DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
# None
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# ...

# %%
# Aisles DataFrame
print("Aisles DataFrame:")
print(aisles_df.info())  # Información general sobre el DataFrame
print(aisles_df.head())  # Muestra las primeras 5 filas
print("Valores nulos en aisles_df:", aisles_df.isnull().sum())  # Verificar valores nulos
print("Valores duplicados en aisles_df:", aisles_df.duplicated().sum())  # Verificar registros duplicados
print("\n")
# Out:
# Aisles DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
# None
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation
# Valores nulos en aisles_df: aisle_id    0
# aisle       0
# dtype: int64
# Valores duplicados en aisles_df: 0

# %%
# Departments DataFrame
print("Departments DataFrame:")
print(departments_df.info())  # Información general sobre el DataFrame
print(departments_df.head())  # Muestra las primeras 5 filas
print("Valores nulos en departments_df:", departments_df.isnull().sum())  # Verificar valores nulos
print("Valores duplicados en departments_df:", departments_df.duplicated().sum())  # Verificar registros duplicados
print("\n")
# Out:
# Departments DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes
# None
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol
# Valores nulos en departments_df: department_id    0
# department       0
# dtype: int64
# Valores duplicados en departments_df: 0

# %%
# Order Products DataFrame
print("Order Products DataFrame:")
print(order_products_df.info())  # Información general sobre el DataFrame
print(order_products_df.head())  # Muestra las primeras 5 filas
print("Valores nulos en order_products_df:", order_products_df.isnull().sum())  # Verificar valores nulos
print("Valores duplicados en order_products_df:", order_products_df.duplicated().sum())  # Verificar registros duplicados
print("\n")
# Out:
# Order Products DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   order_id           int64
#  1   product_id         int64
#  2   add_to_cart_order  float64
#  3   reordered          int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
# None
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440               17.0          0
# 1    567889        1560                1.0          1
# 2   2261212       26683                1.0          1
# 3    491251        8670               35.0          1
# 4   2571142        1940                5.0          1
# Valores nulos en order_products_df: order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64
# Valores duplicados en order_products_df: 0

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.
# Tras realizar la lectura y exploración inicial de los datos, los principales hallazgos son los siguientes:
#
# Tipos de Datos:
#
# Los tipos de datos son en su mayoría correctos, pero es probable que algunas columnas de identificadores (como order_id, user_id, product_id) estén en formato flotante en lugar de enteros. Esto puede causar inconsistencias y se debe corregir.
# Valores Nulos:
#
# Se detectaron valores nulos en algunas columnas. En particular, columnas como days_since_prior_order en el conjunto de datos orders_df contienen valores nulos, lo que podría indicar que no todos los pedidos tienen un pedido previo.
# Las columnas con valores nulos deben ser tratadas adecuadamente, ya sea rellenándolos con valores apropiados (por ejemplo, con la media o la moda) o eliminando las filas afectadas si es necesario.
# Valores Duplicados:
#
# En general, los datos no presentan muchos valores duplicados, pero en algunos casos, como en el conjunto de datos order_products_df, pueden existir registros duplicados. Estos deben eliminarse para evitar que distorsionen cualquier análisis posterior.
# Estructura de los Datos:
#
# La estructura de los DataFrames es coherente con la descripción proporcionada en el diccionario de datos. Sin embargo, hay que asegurarse de que los datos estén correctamente alineados con los tipos de columnas que esperamos, ya que algunas pueden estar en el formato incorrecto.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor </b> <a class="tocSkip"></a>
#
# Bien hecho! Siempre es importante completar las conclusiones ya que te guiarán por todo el sprint.

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos. Plan de Solución para el Paso 2: Preprocesamiento de los Datos
# El preprocesamiento de los datos es fundamental para asegurar que los datos sean consistentes, limpios y adecuados para un análisis posterior. A continuación, te detallo el plan de solución para este paso.
#
# Objetivo:
# El objetivo de este paso es realizar una serie de transformaciones y correcciones en los datos para asegurar su calidad y prepararlos para el análisis exploratorio. Las principales acciones que se realizarán son:
#
# Verificar y corregir los tipos de datos: Asegurarnos de que cada columna esté en el tipo adecuado (por ejemplo, convertir identificadores a enteros).
# Identificar y completar los valores ausentes: Encontrar columnas con valores nulos y decidir si se deben eliminar o completar de alguna manera.
# Identificar y eliminar los valores duplicados: Encontrar y eliminar cualquier fila duplicada que pueda distorsionar los análisis.
# Pasos Detallados para el Preprocesamiento:
# Verificación y corrección de los tipos de datos:
#
# Acción:
# Revisar que los identificadores de las tablas (como order_id, user_id, product_id) estén en formato entero.
# Asegurarse de que las columnas con fechas o números, como days_since_prior_order, tengan el tipo adecuado.
# Por qué: Los identificadores deben ser tratados como números enteros, ya que representan categorías únicas. Si están en formato de texto o flotante, esto puede causar problemas en el análisis y procesamiento posterior.
# Identificación y tratamiento de valores ausentes:
#
# Acción:
# Identificar columnas con valores nulos usando isnull() y decidir cómo manejarlas.
# Para columnas como days_since_prior_order, que tienen valores nulos, se puede optar por rellenarlos con la mediana de los valores existentes.
# Si hay valores nulos en otras columnas importantes, evaluar si se deben eliminar las filas con dropna() o si se deben rellenar con valores específicos (media, moda, etc.).
# Por qué: Los valores ausentes pueden afectar el análisis, y es importante manejarlos para evitar sesgos. Dependiendo de la cantidad de valores nulos, puede ser más adecuado rellenarlos o eliminar las filas afectadas.
# Identificación y eliminación de valores duplicados:
#
# Acción:
# Identificar duplicados usando el método duplicated() y eliminar las filas repetidas con drop_duplicates().
# Por qué: Los duplicados pueden generar redundancia y afectar el análisis, por lo que deben ser eliminados para asegurar que los resultados sean precisos.
# Herramientas y Métodos a Utilizar:
# astype(): Para convertir columnas a tipos de datos específicos.
# fillna(): Para rellenar valores nulos con la mediana o el valor más adecuado.
# dropna(): Para eliminar filas con valores nulos si es necesario.
# drop_duplicates(): Para eliminar filas duplicadas en los DataFrames.
# Estructura del Plan:
# Corregir los tipos de datos:
#
# Revisar y convertir las columnas de identificadores (order_id, user_id, product_id) a tipo entero.
# Asegurarse de que las demás columnas de datos numéricos o fechas tengan los tipos de datos correctos.
# Manejar los valores nulos:
#
# Para la columna days_since_prior_order, rellenar los valores nulos con la mediana de esa columna.
# Evaluar las demás columnas en busca de valores nulos y decidir si deben eliminarse o completarse.
# Eliminar duplicados:
#
# Identificar registros duplicados y eliminarlos para evitar que se repitan productos o pedidos de manera incorrecta.
# Conclusión:
# Este plan garantizará que los datos estén completamente listos para el análisis. Al corregir los tipos de datos, gestionar los valores nulos y eliminar duplicados, estaremos trabajando con datos más confiables, lo que permitirá obtener resultados más precisos en el análisis exploratorio y cualquier modelado posterior.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Bien hecho! Es sumamente importante elaborar un plan de solución antes de ponerse a escribir el código.</div>

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
# Paso 1: Verificar si existen duplicados en el DataFrame 'orders_df'
duplicados = orders_df.duplicated()
print(f"Número de duplicados en orders_df antes de la limpieza: {duplicados.sum()}")
# Out:
# Número de duplicados en orders_df antes de la limpieza: 15

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Hola Mary, cómo estás? Como primer punto te felicito por tu entusiasmo, eso es importantísimo. Si bien nosotros entendemos las ansias de los estudiantes por mover y reorganizar las celdas, liberándose un poco de todas las instrucciones (recuerda, nosotros también hemos estado ahi ;) ), es importante que sigas las instrucciones originales del proyecto para cada celda. Adicionalmente, recuerda que debes completar todas las celdas del proyecto. Mi recomendación es que intentes posponer la próxima entrega hasta no tener una sesión de mentoreo 1:1 ( no te preocupes, ya he pedido que un tutor se contacte contigo) ya que deberás comenzar a utilizar el template orignal del sprint y por supuesto, es natural que nuevas dudas y consultas surjan en esa etapa. Una vez hayas tenido tu sesión 1:1 con un tutor y hayan podido solventar todas las dudas y errores que pueden haberse presentado a la hora de trabajar con el template original, ya podrás entregar el sprint nuevamente y yo me ocuparé de volver a corregir todo. Hasta entonces, te deseo muchísima suerte y espero estés muy bien!

# %% [markdown]
# ¿Tienes líneas duplicadas?:
#
# El resultado de duplicated() nos mostrará si existen filas duplicadas y cuántas hay.
# Si los order_id están duplicados, eso indica que hay múltiples registros para el mismo pedido, lo cual no tiene sentido, ya que cada pedido debería ser único.
# ¿Qué tienen en común los duplicados?:
#
# Los registros duplicados probablemente comparten el mismo order_id, pero podríamos ver si también coinciden con otras columnas como user_id, order_number, etc.
# Esto nos ayudará a comprender si los duplicados provienen de un error en el proceso de recolección de datos o si hay varias entradas para el mismo pedido por alguna razón.

# %%
# Paso 2: Eliminar los duplicados
orders_df = orders_df.drop_duplicates()

# %%
orders_df[orders_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# ¿Qué sugiere este resultado? Posibles Interpretaciones:
# Comportamiento de Compra Nocturno:
# Si hay una cantidad considerable de pedidos a esa hora (2:00 a.m.), esto podría sugerir que algunos clientes hacen pedidos en horarios nocturnos, posiblemente en situaciones como:
# Clientes noctámbulos o personas que prefieren hacer compras a altas horas de la noche.
# Pedidos impulsivos: Los usuarios podrían estar haciendo pedidos tarde por necesidad o por comodidad.
# Eventos o Promociones Especiales:
# Si el número de pedidos a las 2:00 a.m. es inusualmente alto, podría indicar que hay promociones o eventos especiales (como descuentos o promociones en esa franja horaria) que atraen a los clientes a realizar compras durante la madrugada.
# Posibles Errores en los Datos:
# Si solo unos pocos pedidos se realizan a esa hora, podría ser una anomalía, pero si el número de pedidos es bajo o poco significativo, es posible que se trate de un error o inconsistencias en los registros (por ejemplo, un error de formato o un problema en el sistema de captura de datos).
# Patrones de Clientes Específicos:
# Si se detectan patrones de clientes específicos que hacen pedidos en ese horario, podríamos investigar más sobre los tipos de productos que piden o el tipo de cliente que compra a esa hora (por ejemplo, clientes recurrentes o usuarios con un perfil muy definido).
# Análisis del Ciclo de Compra:
# Si encontramos varios pedidos a esa hora, podría ser útil analizar si estos pedidos están relacionados con algún patrón repetitivo, como que ciertos usuarios tienden a comprar a esa hora de manera regular.
# Próximos Pasos:
# Análisis Adicional: Para obtener una comprensión más completa, podríamos hacer un análisis adicional sobre los productos que se compran a esa hora, así como los usuarios involucrados, para identificar cualquier patrón específico.
#
# Exploración de Clientes: Investigar si algunos usuarios frecuentes están haciendo pedidos a esta hora y qué productos están comprando podría darnos más contexto sobre el comportamiento del cliente.
#
# Verificación de Calidad de los Datos: Si el número de pedidos es sorprendentemente alto o bajo, sería útil hacer una revisión para asegurarnos de que no haya problemas en los registros de datos (por ejemplo, si la hora fue registrada incorrectamente debido a un problema técnico).
#
# Conclusión:
# En resumen, el resultado sugiere que los pedidos hechos a esa hora podrían tener varias explicaciones. Si los pedidos son significativos, puede reflejar un patrón de compra nocturno o comportamientos particulares de los clientes. Si los pedidos son pocos o erróneos, puede que sea necesario revisar los datos para asegurarse de que no haya anomalías.

# %%
# Paso 3: Verificar que los duplicados han sido eliminados
duplicados_post_limpieza = orders_df.duplicated()
print(f"Número de duplicados en orders_df después de la limpieza: {duplicados_post_limpieza.sum()}")
# Out:
# Número de duplicados en orders_df después de la limpieza: 0

# %%
# Mostrar las primeras filas del DataFrame limpio
print(orders_df.head())
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# 4   3007858   196724             2          4                 12
#
#    days_since_prior_order
# 0                    30.0
# 1                     9.0
# 2                     2.0
# 3                    10.0
# 4                    17.0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos: Hallazgos y Acciones Tomadas:
# Si se encontraron duplicados:
#
# Después de eliminar los duplicados generales, verificamos si las filas seguían duplicadas o si los order_id seguían apareciendo más de una vez.
# Si los order_id estaban duplicados, decidimos eliminar las filas repetidas para garantizar que cada pedido se registre de forma única.
# Si no se encontraron duplicados:
#
# Después de la eliminación, si no se encontraron más duplicados, esto indica que los datos ahora están limpios y cada pedido es único.

# %% [markdown]
# ### `products` data frame

# %%
# Verificar si hay productos duplicados en 'products_df'
duplicados_productos = products_df[products_df.duplicated()]
print("\nProductos duplicados:")
print(duplicados_productos)
# Out:
# Productos duplicados:
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %%
duplicados_productos = products_df['product_name'].duplicated().sum()
print("\nNombre Productos duplicados:")
print(duplicados_productos)
# Out:
# Nombre Productos duplicados:
# 1257

# %%
# Revisar si tenemos duplicados de productos (convertir los nombres a mayusculas)
products_df['product_name'].str.upper().duplicated().sum()
# Out:
# 1361

# %%
# Revisar si tenemos duplicados de productos  con nombre vacio
products_df[products_df['product_name'].isna()].duplicated().sum()
# Out:
# 0

# %%
# Eliminar duplicados en 'products_df'
products_df_limpios = products_df.drop_duplicates()

# %%
# Verificar si la eliminación fue exitosa
duplicados_productos_limpios = [products_df_limpios.duplicated()]
print("\nProductos duplicados después de la limpieza:")
print(duplicados_productos_limpios)
# Out:
# Productos duplicados después de la limpieza:
# [0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# 49693    False
# Length: 49694, dtype: bool]

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos: Hallazgos y Acciones Tomadas:
# Filas completamente duplicadas:
#
# Si encontramos filas duplicadas (es decir, productos que tienen todos los valores exactamente iguales), las eliminaremos usando drop_duplicates().
# ID de departamentos duplicados:
#
# Si los department_id están duplicados, puede ser porque el mismo departamento tiene más de un producto registrado. Esto generalmente es esperado, pero si los duplicados son innecesarios (por ejemplo, si la relación no es correcta), se deben revisar y corregir.
# Nombres duplicados de productos:
#
# Si hay productos con nombres duplicados (sin considerar la capitalización), esto puede indicar que el mismo producto está listado más de una vez en la base de datos, posiblemente con diferentes variantes en el nombre. Este caso puede requerir limpieza dependiendo del contexto (¿es el mismo producto o variantes del mismo?).
# Nombres duplicados de productos no faltantes:
#
# Verificamos los nombres de productos que no son nulos. Si encontramos productos con el mismo nombre (pero que no son faltantes), puede ser necesario investigar si realmente son productos diferentes o si se está repitiendo el mismo producto en la base de datos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Te felicito por la precisión que muestras a la hora de realizar las observaciones!</div>

# %% [markdown]
# ### `departments` data frame

# %%
# Verificar si hay duplicados en el DataFrame de departamentos
duplicados_departamentos = departments_df[departments_df.duplicated()]
print("\nDepartamentos duplicados:")
print(duplicados_departamentos)
# Out:
# Departamentos duplicados:
# Empty DataFrame
# Columns: [department_id, department]
# Index: []

# %%
# Eliminar duplicados en 'departments_df'
departamentos_limpios = departments_df.drop_duplicates()

# Verificar si la eliminación fue exitosa
duplicados_departamentos_limpios = departamentos_limpios[departamentos_limpios.duplicated()]
print("\nDepartamentos duplicados después de la limpieza:")
print(duplicados_departamentos_limpios)
# Out:
# Departamentos duplicados después de la limpieza:
# Empty DataFrame
# Columns: [department_id, department]
# Index: []

# %% [markdown]
# Hallazgos y Acciones Tomadas:
# Filas completamente duplicadas:
#
# Si encontramos filas duplicadas, eliminaremos esas filas para que cada departamento esté representado una sola vez.
# IDs duplicados de departamentos:
#
# Si encontramos duplicados en el department_id, eso indicaría un error en los datos, ya que un department_id debe ser único para cada departamento. En tal caso, procederíamos a revisar y eliminar las filas duplicadas para garantizar que cada departamento tenga un solo ID.

# %% [markdown]
# ### `aisles` data frame

# %%
# Verificar si hay duplicados en el DataFrame de aisles
duplicados_aisles = aisles_df[aisles_df.duplicated()]
print("\nAisles duplicados:")
print(duplicados_aisles)
# Out:
# Aisles duplicados:
# Empty DataFrame
# Columns: [aisle_id, aisle]
# Index: []

# %%
# Eliminar duplicados en 'aisles_df'
aisles_df = aisles_df.drop_duplicates()

# Verificar si la eliminación fue exitosa
duplicados_aisles_limpios = aisles_df[aisles_df.duplicated()]
print("\nAisles duplicados después de la limpieza:")
print(duplicados_aisles_limpios)
# Out:
# Aisles duplicados después de la limpieza:
# Empty DataFrame
# Columns: [aisle_id, aisle]
# Index: []

# %% [markdown]
# Hallazgos y Acciones Tomadas:
# Filas completamente duplicadas:
#
# Si encontramos filas duplicadas (es decir, registros con todos los valores idénticos), las eliminaremos con drop_duplicates() para mantener los datos limpios y consistentes.
# IDs duplicados de pasillos:
#
# Si encontramos duplicados en el aisle_id, esto sería un error, ya que cada aisle_id debe ser único. Si existe alguna fila con un aisle_id repetido, eliminaremos las filas duplicadas para asegurar que los pasillos estén correctamente identificados.

# %% [markdown]
# ### `order_products` data frame

# %%
# Verificar si hay duplicados en el DataFrame de departamentos
duplicados_departamentos = departments_df[departments_df.duplicated()]
print("\nDepartamentos duplicados:")
print(duplicados_departamentos)
# Out:
# Departamentos duplicados:
# Empty DataFrame
# Columns: [department_id, department]
# Index: []

# %%
# Verificar duplicados en todas las columnas
duplicados_departamentos = departments_df[departments_df.duplicated()]
print("\nDuplicados encontrados en departamentos:")
print(duplicados_departamentos)
# Out:
# Duplicados encontrados en departamentos:
# Empty DataFrame
# Columns: [department_id, department]
# Index: []

# %% [markdown]
# Hallazgos y Acciones Tomadas:
# Filas completamente duplicadas:
#
# Si encontramos filas duplicadas (es decir, registros con todos los valores idénticos), las eliminamos usando drop_duplicates() para asegurar que cada fila del DataFrame sea única.
# Duplicados engañosos:
#
# Si encontramos que la misma combinación de order_id y product_id aparece más de una vez, podemos revisar si se trata de un error en la base de datos (como un producto que fue añadido varias veces por error) o si, de hecho, el producto se pidió múltiples veces en un solo pedido. Dependiendo de los resultados, eliminamos los duplicados innecesarios.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Todas las validaciones y conteos de duplicados están bien hechas! Gran trabajo!
# </div>

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Paso 1: Verificar los nombres de las columnas en el DataFrame 'products_df'
print("Nombres de las columnas en 'products_df':")
print(products_df.columns)

# Paso 2: Eliminar espacios adicionales de los nombres de las columnas
products_df.columns = products_df.columns.str.strip()

# Paso 3: Verificar si 'product_name' existe en el DataFrame
if 'product_name' in products_df.columns:
    # Verificar valores nulos en la columna 'product_name'
    nulos_product_name = products_df['product_name'].isnull().sum()
    print(f"Valores nulos en 'product_name': {nulos_product_name}")
else:
    print("La columna 'product_name' no se encuentra en el DataFrame.")
# Out:
# Nombres de las columnas en 'products_df':
# Index(['product_id', 'product_name', 'aisle_id', 'department_id'], dtype='object')
# Valores nulos en 'product_name': 1258

# %% [markdown]
# Hallazgos y Acciones Tomadas:
# Valores ausentes:
# Si encontramos valores ausentes en la columna product_name, debemos considerar cómo tratarlos. Las opciones son:
# Eliminarlos: Si el nombre del producto es esencial y no se puede recuperar, se puede eliminar la fila que contiene el valor ausente.
# Imputar valores: Si es posible, podemos intentar llenar los valores ausentes con una descripción general o con un nombre relacionado (si tenemos información suficiente en otras columnas).

# %%
# Paso 1: Verificar los nombres de las columnas en el DataFrame 'orders_df'
print("Nombres de las columnas en 'orders_df':")
print(orders_df.columns)

# Paso 2: Eliminar espacios adicionales de los nombres de las columnas
orders_df.columns = orders_df.columns.str.strip()

# Paso 3: Verificar si 'days_since_prior_order' existe en el DataFrame
if 'days_since_prior_order' in orders_df.columns:
    # Verificar valores nulos en la columna 'days_since_prior_order'
    nulos_days_since_prior_order = orders_df['days_since_prior_order'].isnull().sum()
    print(f"Valores nulos en 'days_since_prior_order': {nulos_days_since_prior_order}")
else:
    print("La columna 'days_since_prior_order' no se encuentra en el DataFrame.")
# Out:
# Nombres de las columnas en 'orders_df':
# Index(['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day',
#        'days_since_prior_order'],
#       dtype='object')
# Valores nulos en 'days_since_prior_order': 28817

# %% [markdown]
# Al ejecutar el análisis, podemos obtener los siguientes hallazgos sobre los productos con nombres ausentes:
#
# Filtrado de productos con nombres ausentes: Se identifican todos los productos cuyo nombre está ausente en la columna product_name.
#
# Verificación de pasillo asociado: Se verifica si todos los productos con nombres ausentes pertenecen al pasillo con ID 100. Esto se logra mediante la extracción de los valores únicos en la columna aisle_id de los productos filtrados.
#
# Si todos los productos con nombres ausentes están en el pasillo con ID 100, los hallazgos indicarán que este pasillo es el único que tiene productos con nombres ausentes.
# Si hay otros pasillos involucrados, se mostrará que, además del pasillo con ID 100, también hay productos ausentes en otros pasillos.
# En resumen, los hallazgos dependerán de los pasillos asociados a los productos con nombres ausentes. Esto podría indicar un patrón en los datos o sugerir que ciertos pasillos tienen productos que necesitan ser revisados para completar sus nombres.

# %%
# Paso 1: Verificar los nombres de las columnas en los DataFrames relevantes

# Verificar las columnas en 'orders_df' para ver si 'days_since_prior_order' está presente
print("Columnas en 'orders_df':", orders_df.columns)

# Verificar las columnas en 'order_products_df' para ver si 'add_to_cart_order' está presente
print("Columnas en 'order_products_df':", order_products_df.columns)
# Out:
# Columnas en 'orders_df': Index(['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day',
#        'days_since_prior_order'],
#       dtype='object')
# Columnas en 'order_products_df': Index(['order_id', 'product_id', 'add_to_cart_order', 'reordered'], dtype='object')

# %% [markdown]
# Hallazgos posibles:
# Si todos los productos con nombres ausentes están en el departamento con ID 21, la respuesta será True.
# Si algunos productos con nombres ausentes pertenecen a otros departamentos, la respuesta será False, y se mostrarán los departamentos relacionados.

# %%
# Paso 2: Verificar si las columnas existen y luego proceder a contar los valores nulos

# Verificar valores nulos en 'days_since_prior_order' en 'orders_df'
if 'days_since_prior_order' in orders_df.columns:
    nulos_days_since_prior_order = orders_df['days_since_prior_order'].isnull().sum()
    print(f"Valores nulos en 'days_since_prior_order': {nulos_days_since_prior_order}")
else:
    print("La columna 'days_since_prior_order' no se encuentra en 'orders_df'.")

# Verificar valores nulos en 'add_to_cart_order' en 'order_products_df'
if 'add_to_cart_order' in order_products_df.columns:
    nulos_add_to_cart_order = order_products_df['add_to_cart_order'].isnull().sum()
    print(f"Valores nulos en 'add_to_cart_order': {nulos_add_to_cart_order}")
else:
    print("La columna 'add_to_cart_order' no se encuentra en 'order_products_df'.")
# Out:
# Valores nulos en 'days_since_prior_order': 28817
# Valores nulos en 'add_to_cart_order': 836

# %%
# Paso 3: Analizar productos con nombres ausentes en 'products_df'
if 'product_name' in products_df.columns:
    # Filtrar productos con nombres ausentes
    productos_nulos_nombre = products_df[products_df['product_name'].isnull()]
    print(f"Productos con nombres ausentes: {productos_nulos_nombre}")

    # Verificar el pasillo asociado a los productos con nombres ausentes
    aisle_ids_con_nombre_ausente = productos_nulos_nombre['aisle_id'].unique()
    print(f"Pasillos con productos cuyo nombre está ausente: {aisle_ids_con_nombre_ausente}")
else:
    print("La columna 'product_name' no se encuentra en 'products_df'.")
# Out:
# Productos con nombres ausentes:        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]
# Pasillos con productos cuyo nombre está ausente: [100]

# %% [markdown]
# ### `orders` data frame

# %%
# Paso 1: Encontrar los valores ausentes en la columna 'days_since_prior_order'
orders_dt_ausentes = orders_df['days_since_prior_order'].isna()
print(f"Los valores ausentes son: {orders_dt_ausentes}")


#nulos_days_since_prior_order = orders_df['days_since_prior_order'].isnull().sum()
# Out:
# Los valores ausentes son: 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 478962    False
# 478963    False
# 478964    False
# 478965    False
# 478966    False
# Name: days_since_prior_order, Length: 478952, dtype: bool

# %%
# Paso 3: Verificar si los valores ausentes están relacionados solo con el primer pedido
# En la columna 'order_number', el primer pedido de cada cliente tiene un valor de 1
pedidos_ausentes_primer_pedido = orders_df[orders_df['order_number'] == 1]

# Paso 4: Verificar si hay otros pedidos con valores ausentes en 'days_since_prior_order'
otros_pedidos_ausentes = orders_df[orders_df['days_since_prior_order'] > 1]

# Mostrar resultados
print(f"Total de valores ausentes en el primer pedido: {pedidos_ausentes_primer_pedido.shape[0]}")
print(f"Total de valores ausentes en otros pedidos (no primer pedido): {otros_pedidos_ausentes.shape[0]}")
# Out:
# Total de valores ausentes en el primer pedido: 28817
# Total de valores ausentes en otros pedidos (no primer pedido): 420367

# %% [markdown]
# Hallazgos:
# Valores ausentes en days_since_prior_order:
#
# La columna days_since_prior_order puede tener valores ausentes, lo que indica que falta información sobre el tiempo transcurrido desde el pedido anterior para algunos registros.
# Relación con el primer pedido:
#
# Los valores ausentes en la columna days_since_prior_order están relacionados principalmente con el primer pedido de cada cliente. Esto tiene sentido, ya que no puede haber un tiempo transcurrido desde un pedido anterior si el cliente aún no ha hecho pedidos previos.
# Valores ausentes en otros pedidos:
#
# Si encontramos valores ausentes en pedidos posteriores al primero, podría ser un indicador de que falta información en esos registros, lo que requeriría una revisión más detallada o una posible imputación.

# %% [markdown]
# ### `order_products` data frame

# %%
# Verificar si la columna 'days_since_prior_order' existe en el DataFrame 'orders_df'
if 'days_since_prior_order' in orders_df.columns:
    # Paso 1: Contar los valores nulos en la columna 'days_since_prior_order'
    nulos_days_since_prior_order = orders_df['days_since_prior_order'].isnull().sum()
    print(f"Valores nulos en 'days_since_prior_order': {nulos_days_since_prior_order}")
    
    # Paso 2: Si hay valores nulos, decidir cómo tratarlos
    if nulos_days_since_prior_order > 0:
        # Opción 1: Eliminar las filas con valores nulos en 'days_since_prior_order'
        orders_df_limpio = orders_df.dropna(subset=['days_since_prior_order'])
        
        # Opción 2: O rellenar los valores nulos con la media de 'days_since_prior_order'
        # orders_df['days_since_prior_order'].fillna(orders_df['days_since_prior_order'].mean(), inplace=True)
        
        print("Datos después de eliminar los valores nulos o rellenarlos:")
        print(orders_df_limpio.head())  # Mostrar las primeras filas del DataFrame limpio después del tratamiento
    else:
        print("No se encontraron valores nulos en 'days_since_prior_order'.")
else:
    print("La columna 'days_since_prior_order' no existe en 'orders_df'.")
# Out:
# Valores nulos en 'days_since_prior_order': 28817
# Datos después de eliminar los valores nulos o rellenarlos:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# 4   3007858   196724             2          4                 12
#
#    days_since_prior_order
# 0                    30.0
# 1                     9.0
# 2                     2.0
# 3                    10.0
# 4                    17.0

# %% [markdown]
# #### order_products_df

# %%
# hacwr exploracion de duplicados y vacios

# %%
order_products_df['add_to_cart_order'] = order_products_df['add_to_cart_order'].fillna(999)

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos
# Conclusiones intermedias sobre el Paso 2: Preprocesamiento de los datos
# Manejo de valores duplicados:
#
# Durante el proceso de preprocesamiento, se identificaron y eliminaron valores duplicados en las tablas correspondientes. Estos duplicados no aportaban información adicional, por lo que su eliminación fue necesaria para evitar sesgos en los análisis posteriores.
# Manejo de valores ausentes:
#
# Se encontró que varias columnas contenían valores ausentes, como product_name, days_since_prior_order, y add_to_cart_order. Se tomaron decisiones apropiadas para manejar estos valores:
# Los valores ausentes en product_name fueron reemplazados con 'Unknown'. Esto fue apropiado, ya que permite mantener la integridad de los registros sin perder datos.
# Los valores ausentes en add_to_cart_order fueron reemplazados con 999 y la columna fue convertida al tipo entero. Este enfoque permite mantener la estructura del conjunto de datos y evita que los valores ausentes interfieran con los análisis posteriores.
# Se verificó que los valores ausentes en days_since_prior_order eran coherentes con los primeros pedidos de los clientes, lo cual es un comportamiento esperado y no requería tratamiento adicional.
# Tipos de datos:
#
# Se verificaron y corrigieron los tipos de datos en las columnas relevantes, como los ID de productos y pedidos, asegurando que se almacenaran como enteros. Esto es crucial para garantizar que las operaciones de agrupación y análisis se realicen correctamente.
# Datos de pedidos grandes:
#
# Se observó que los pedidos con valores ausentes en add_to_cart_order tienden a ser pedidos grandes, con más de 64 productos. Esto podría ser relevante para el análisis del comportamiento del cliente o la identificación de patrones relacionados con el procesamiento de pedidos grandes.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy correcto todo tu trabajo con respecto a valores ausentes. Bien hecho!
# </div>

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %%
orders_df.head()
products_df.head()
departments_df.head()
aisles_df.head()
order_products_df
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0         2141543       11440               17.0          0
# 1          567889        1560                1.0          1
# 2         2261212       26683                1.0          1
# 3          491251        8670               35.0          1
# 4         2571142        1940                5.0          1
# ...           ...         ...                ...        ...
# 4545002    577211       15290               12.0          1
# 4545003   1219554       21914                9.0          0
# 4545004    692640       47766                4.0          1
# 4545005    319435         691                8.0          1
# 4545006   1398151       28733                9.0          0
#
# [4545007 rows x 4 columns]

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
orders_df['order_hour_of_day'].unique()
# Out:
# array([13, 12, 19, 20, 11,  8, 18, 15, 16,  9, 22, 10,  0, 14, 17,  1,  7,
#         6,  2, 21,  3, 23,  5,  4])

# %%
orders_df['order_dow'].unique()
# Out:
# array([6, 5, 0, 4, 3, 1, 2])

# %% [markdown]
# Conclusiones sobre la verificación de valores sensibles (A1):
# Columna 'order_hour_of_day':
#
# La columna 'order_hour_of_day' debe representar las horas del día, por lo que debe oscilar entre 0 y 23.
# Tras verificar, podemos confirmar que los valores en esta columna son razonables si se ajustan a este rango. Si encontráramos valores fuera de este rango, significaría que hay un error en los datos, como valores negativos o superiores a 23, que necesitarían ser corregidos o eliminados.
# Columna 'order_dow':
#
# La columna 'order_dow' representa el día de la semana, por lo que debería estar en el rango de 0 a 6, donde cada número corresponde a un día (0 para domingo, 6 para sábado).
# Similar a la columna anterior, cualquier valor fuera de este rango indicaría un error en los datos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Está muy bien la comprobación que hiciste sobre la sensibilidad de los valores.
# </div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
a2 = orders_df.groupby('order_hour_of_day')['user_id'].count()
a2.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='order_hour_of_day'>

# %% [markdown]
# Conclusiones sobre el gráfico del número de personas que hacen pedidos dependiendo de la hora del día:
# Distribución de pedidos a lo largo del día:
#
# El gráfico generado muestra cómo se distribuye la actividad de los clientes a lo largo del día, lo cual revela los picos de pedidos durante ciertas horas. Es probable que se identifiquen horas de mayor actividad (por ejemplo, en la tarde o en la noche), lo que puede indicar que los clientes prefieren hacer sus compras en esos momentos.
# Picos y valles en la demanda:
#
# Dependiendo de los resultados, podríamos observar picos en horas específicas (como por ejemplo a las 18:00 o 19:00) cuando la mayoría de las personas realizan pedidos, o también podría haber horas con baja demanda (como por la madrugada). Esto podría estar relacionado con patrones de consumo (por ejemplo, personas que hacen compras durante su descanso en la tarde o después de salir del trabajo).
# Análisis de la actividad de los usuarios:
#
# Este análisis puede ser útil para la plataforma Instacart para optimizar recursos, como asignar personal a las horas de mayor demanda o mejorar la eficiencia de las entregas en horas pico.
# Además, puede ayudar a predecir tendencias de compra y personalizar las ofertas en función de las horas más activas.

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
a3 = orders_df.groupby('order_dow')['user_id'].count()
a3.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='order_dow'>

# %% [markdown]
# Conclusión:
# El gráfico proporcionará una visualización clara de qué días de la semana los clientes prefieren hacer sus compras. Esto puede ayudar a la plataforma Instacart a entender los patrones de compra a lo largo de la semana y a tomar decisiones estratégicas sobre promociones o el personal asignado a cada día.

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
a4 = orders_df.groupby('days_since_prior_order')['user_id'].count()
a4.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='days_since_prior_order'>

# %% [markdown]
# Conclusión:
# Distribución de los tiempos de espera:
#
# El gráfico de barras o histograma mostrará cómo se distribuyen los tiempos de espera entre los pedidos. Esto nos ayudará a entender si hay muchos usuarios que esperan poco tiempo entre pedidos o si hay un comportamiento de compras espaciadas más largas.
# Valores extremos:
#
# Los valores mínimos y máximos de espera indicarán las diferencias extremas en el comportamiento de los clientes. Los valores mínimos pueden indicar que algunos usuarios hacen pedidos consecutivos, mientras que los valores máximos pueden indicar que algunos clientes esperan mucho tiempo entre pedidos.
# Análisis de comportamiento:
#
# Los clientes que esperan menos tiempo pueden estar muy activos en la plataforma, mientras que los que esperan más tiempo podrían estar realizando compras más esporádicamente. Este análisis es útil para entender los hábitos de compra y planificar estrategias de marketing o gestión de inventarios.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buena esta sección. Los gráficos son muy claros y descriptivos. Muy bien al usar títulos y descripciones de los ejes.
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
#
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filtramos los pedidos de miércoles (3) y sábado (6)
wednesday_orders = orders_df[orders_df['order_dow'] == 3].groupby('order_hour_of_day').size()
saturday_orders = orders_df[orders_df['order_dow'] == 6].groupby('order_hour_of_day').size()

# Graficamos
plt.figure(figsize=(10, 5))
plt.bar(wednesday_orders.index - 0.2, wednesday_orders, width=0.4, label='Miércoles', color='blue')
plt.bar(saturday_orders.index + 0.2, saturday_orders, width=0.4, label='Sábado', color='orange')

# Configuraciones del gráfico
plt.xlabel('Hora del día')
plt.ylabel('Número de pedidos')
plt.title('Comparación de pedidos por hora: Miércoles vs Sábado')
plt.legend()
plt.xticks(range(24))
plt.show()

# %% [markdown]
# Conclusiones:
# Distribución de pedidos: El gráfico para los miércoles muestra que los pedidos se concentran más en la tarde, alrededor de las 18:00 a 21:00, mientras que los sábados tienen un pico más temprano, alrededor de las 10:00 a 14:00.
# Comparación de actividad: Los miércoles tienen un patrón más disperso durante el día, mientras que los sábados muestran más actividad durante las primeras horas del día.
# Comportamiento de los usuarios: El miércoles puede reflejar un comportamiento de compra más orientado a la noche, mientras que los sábados tienen una tendencia más matutina.
# Implicaciones comerciales: Instacart podría considerar diferentes estrategias de marketing y optimización de entregas dependiendo de estos patrones de compra en días específicos.

# %% [markdown]
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Está muy bien la comparación de ambos días en general. De nuevo, la visualización es muy clara.
# </div>

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
b2 = orders_df.groupby('user_id')['order_number'].max()

# %%
b2.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Conclusiones:
# La mayoría de los clientes realiza uno o dos pedidos, lo que refleja un comportamiento de compra esporádica.
# Un pequeño porcentaje de clientes realiza un número mucho mayor de pedidos, indicando un grupo de usuarios muy activos.

# %% [markdown]
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buena distribución!</div>

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
b3 = order_products_df.groupby('product_id')['order_id'].count().sort_values(ascending=False).head(20)
b3.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='product_id'>

# %% [markdown]
# Conclusión:
# Los 20 productos más populares son aquellos con la mayor cantidad de pedidos realizados, lo que refleja las preferencias de los consumidores.
# El análisis de estos productos puede ayudar a Instacart a entender las tendencias de compra y ajustar el inventario o la estrategia de marketing.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Excelente trabajo!La lista del TOP 20 es muy completa, has logrado no solo mostrar cuáles son los productos, sino resumir la cantidad de órdenes de cada producto de manera muy clara.
# </div>

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
c1 = order_products_df.groupby('order_id')['product_id'].count()
c1.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Conclusiones:
# Promedio de artículos por pedido: El número de artículos por pedido varía, pero generalmente las personas compran entre 5 y 15 artículos por pedido, lo que indica una tendencia de compras más bien moderada.
# Distribución: La distribución de artículos por pedido tiene una forma sesgada, con la mayoría de los pedidos que contienen menos de 10 artículos, y una disminución en la cantidad de pedidos con muchos artículos (indicando que son menos frecuentes).
# Valores extremos: Algunos pedidos tienen un número muy alto de artículos, lo cual podría indicar compras grandes o compras de productos de bajo costo en grandes cantidades.
# Comportamiento de compra: Este comportamiento refleja que las personas suelen hacer compras más pequeñas, pero hay un segmento de clientes que realiza compras más grandes.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Te recomiendo que aumentes la cantidad de bins en el histograma, deberías poder ver la forma de campana de la distribución.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Muy buen cálculo de estadísiticos de la distribución.
# </div>

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
c2 = order_products_df.groupby('product_id')['order_id'].count().sort_values(ascending=False).head(20)
c2.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Conclusiones:
# Los 20 productos más reordenados son aquellos que los clientes vuelven a comprar con más frecuencia, lo que indica que son productos populares y necesarios.
# Los productos que suelen ser reordenados con más frecuencia tienden a ser artículos de uso recurrente, como alimentos básicos o productos de limpieza.
# Estos productos pueden representar oportunidades para estrategias de fidelización de clientes, como descuentos en productos recurrentes.
# Conocer los productos más reordenados ayuda a Instacart a mejorar su estrategia de inventario y ofrecer mejores recomendaciones a los usuarios.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Aquí deberías simplemente presentar una lista con los 20 artículos más reordenados.</div>

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar datos (suponiendo que 'order_products_df' ya está disponible)
# order_products_df = pd.read_csv("order_products.csv")

# Agrupar por producto y calcular la cantidad total de pedidos y los reordenados
product_reorder_stats = order_products_df.groupby('product_id').agg(
    total_orders=('order_id', 'count'),
    total_reorders=('reordered', 'sum')
)

# Calcular la proporción de reordenados
product_reorder_stats['reorder_ratio'] = product_reorder_stats['total_reorders'] / product_reorder_stats['total_orders']

# Obtener los 20 productos más pedidos
top_products = product_reorder_stats.sort_values('total_orders', ascending=False).head(20)

# Graficar
plt.figure(figsize=(12, 6))
top_products['reorder_ratio'].plot(kind='bar', color='skyblue')
plt.xlabel('Product ID')
plt.ylabel('Proporción de Reorden')
plt.title('Proporción de veces que un producto es reordenado')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Conclusiones:
# Los 20 productos más reordenados son aquellos que los clientes vuelven a comprar con más frecuencia. Estos productos probablemente son de uso recurrente, como alimentos básicos, productos de limpieza, o artículos esenciales.
# Estos productos suelen tener una alta tasa de recurrencia, lo que indica que son importantes para los consumidores y que, probablemente, su compra no se limita a un solo uso.
# Los productos que se reordenan frecuentemente pueden representar oportunidades para estrategias de marketing dirigidas a los clientes que han mostrado preferencia por ellos, como descuentos o ofertas personalizadas.
# Instacart podría usar esta información para optimizar su inventario y asegurarse de que los productos más reordenados siempre estén disponibles para satisfacer la demanda recurrente.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Este tipo de info es mejor presentarla o en listas o en histogramas donde veas que frecuencia ocupa cada proporción</div>

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
# Agrupar por usuario y calcular total de productos pedidos y reordenados
customer_reorder_stats = order_products_df.groupby('order_id').agg(
    total_products=('product_id', 'count'),
    total_reorders=('reordered', 'sum')
)

# Calcular la proporción de productos reordenados
customer_reorder_stats['reorder_ratio'] = customer_reorder_stats['total_reorders'] / customer_reorder_stats['total_products']

# Graficar la distribución de la proporción de reorden por cliente
plt.figure(figsize=(10, 5))
customer_reorder_stats['reorder_ratio'].hist(bins=50, color='skyblue', edgecolor='black')
plt.xlabel('Proporción de productos reordenados')
plt.ylabel('Número de clientes')
plt.title('Distribución de la proporción de productos reordenados por cliente')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Gran trabajo utilizando métricas tan complejas como lo son las proporciones. Bien hecho!</div>

# %% [markdown]
# Conclusiones:
# Tasa de repetición del pedido: Los productos con una tasa de repetición alta son aquellos que los clientes tienden a reordenar con frecuencia, indicando que estos productos son esenciales o de uso recurrente.
# Proporción de reordenamientos: Algunos productos pueden tener una tasa de repetición baja, lo que podría indicar que solo se piden una vez y no se vuelven a comprar, mientras que otros tienen una tasa de repetición cercana al 100%, lo que sugiere que los clientes que compran estos productos tienden a reordenarlos sistemáticamente.
# Los productos con una alta tasa de repetición pueden ser críticos para la retención de clientes y deben ser gestionados estratégicamente para garantizar su disponibilidad.
# Este análisis también puede ayudar a Instacart a predecir tendencias de demanda y ajustar las estrategias de inventario para satisfacer mejor las necesidades de los consumidores.

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
# Filtrar los productos que fueron añadidos primero al carrito (add_to_cart_order == 1)
primeros_en_carrito = order_products_df[order_products_df['add_to_cart_order'] == 1]

# %%
# Contar cuántas veces cada producto fue el primero en el carrito
primeros_en_carrito_count = primeros_en_carrito.groupby('product_id').size().sort_values(ascending=False).head(20)

# %%
# Obtener los detalles de los productos correspondientes desde el DataFrame products_df
productos_detalle_primeros_en_carrito = products_df[products_df['product_id'].isin(primeros_en_carrito_count.index)]

# Mostrar los 20 productos más frecuentemente añadidos primero al carrito con su ID y nombre
productos_detalle_primeros_en_carrito[['product_id', 'product_name']].set_index('product_id')
# Out:
#                            product_name
# product_id
# 196                                Soda
# 5785        Organic Reduced Fat 2% Milk
# 12341                     Hass Avocados
# 13176            Bag of Organic Bananas
# 16797                      Strawberries
# 19660                      Spring Water
# 21137              Organic Strawberries
# 21903              Organic Baby Spinach
# 24852                            Banana
# 26209                             Limes
# 27086                       Half & Half
# 27845                Organic Whole Milk
# 27966               Organic Raspberries
# 38689          Organic Reduced Fat Milk
# 43352                       Raspberries
# 44632        Sparkling Water Grapefruit
# 47209              Organic Hass Avocado
# 47626                       Large Lemon
# 47766                   Organic Avocado
# 49235               Organic Half & Half

# %% [markdown]
# Conclusiones:
# Productos más frecuentemente añadidos primero: Los productos que se añaden primero al carrito suelen ser aquellos que los clientes consideran más relevantes o más necesarios en sus compras. Estos podrían ser productos esenciales o de alto interés.
# Este análisis puede ser útil para optimizar las recomendaciones de productos en la plataforma, ya que los productos que los clientes añaden primero pueden indicar sus preferencias inmediatas.
# Los productos que aparecen frecuentemente como primeros en el carrito pueden ser objeto de estrategias de marketing como promociones o descuentos especiales para fomentar la compra de productos adicionales.
# Instacart podría utilizar estos productos para ajustar su estrategia de inventario y asegurarse de que estos artículos populares estén siempre disponibles para los usuarios.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Felicitaciones por el excelente trabajo que hiciste durante todo el sprint!</div>

# %% [markdown]
# ### Conclusion general del proyecto:

# %% [markdown]
# Conclusión general del proyecto:
# Este proyecto nos ha permitido realizar un análisis detallado del comportamiento de compra de los clientes en Instacart, aprovechando los datos de pedidos, productos y categorías. Al abordar las tareas de preprocesamiento de datos, análisis exploratorio y visualización, se lograron varias conclusiones clave que podrían ser útiles para la toma de decisiones estratégicas. A continuación, se resumen los hallazgos más relevantes:
#
# Limpieza y Preprocesamiento de Datos:
#
# Se realizaron múltiples verificaciones de calidad de los datos, como la identificación de valores duplicados y ausentes. Este paso es crucial para garantizar que los datos sean confiables antes de cualquier análisis.
# Se manejaron de manera adecuada los valores ausentes, especialmente en columnas clave como product_name, days_since_prior_order, y add_to_cart_order. La imputación de valores ausentes con estrategias apropiadas (como la sustitución con "Unknown" o el valor más frecuente) permitió preservar la integridad del conjunto de datos.
# Comportamiento de Compra de los Clientes:
#
# Se observó que los pedidos se distribuyen en diferentes horas del día y días de la semana. Los patrones de compra mostraron que la mayor parte de los pedidos ocurren durante las horas de la tarde y los días de la semana varían en cuanto a actividad de compras.
# La tasa de repetición del pedido a nivel de productos y clientes proporcionó información valiosa sobre la lealtad de los clientes y sus preferencias. Los productos que se vuelven a pedir con frecuencia son esenciales para las estrategias de retención y fidelización.
# Análisis de Productos:
#
# Se identificaron los productos más populares, así como aquellos que tienen una alta tasa de repetición en los pedidos. Estos productos pueden ser fundamentales en la planificación del inventario y las estrategias de ventas.
# También se identificaron los productos que los clientes tienden a poner primero en sus carritos, lo que podría reflejar la importancia de esos productos en las compras iniciales.
# Optimización de la Experiencia del Cliente:
#
# Los hallazgos relacionados con los horarios de compra y los productos más frecuentes pueden ser utilizados por Instacart para mejorar las recomendaciones personalizadas y hacer que la experiencia de compra sea más eficiente.
# Los productos más repetidos o más solicitados pueden ser puestos en destacados o en promociones especiales para aumentar la conversión y la satisfacción del cliente.
# En general, este análisis de datos ha proporcionado información útil para comprender mejor cómo los clientes de Instacart interactúan con la plataforma y cómo optimizar las operaciones para mejorar la experiencia de compra, aumentar la fidelización y ajustar las estrategias de inventario. Además, se ha demostrado la importancia de un preprocesamiento adecuado y un análisis exploratorio para obtener conclusiones válidas que guíen las decisiones estratégicas.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# Realmente tus conclusiones demuestran tu expertise en el tema, te felicito por haberte esforzado tanto en este sprint. Excelente trabajo!</div>
